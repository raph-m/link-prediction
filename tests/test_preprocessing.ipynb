# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

path_to_data = "../../data/"
nodes_header = ["id", "year", "title", "authors", "journal", "abstract"]
nodes = pd.read_csv(path_to_data+"node_information.csv", names=nodes_header)
nodes.head()
# Out:
#      id  year                                              title  \
# 0  1001  2000              compactification geometry and duality
# 1  1002  2000  domain walls and massive gauged supergravity p...
# 2  1003  2000     comment on metric fluctuations in brane worlds
# 3  1004  2000         moving mirrors and thermodynamic paradoxes
# 4  1005  2000  bundles of chiral blocks and boundary conditio...
#
#                        authors            journal  \
# 0            Paul S. Aspinwall                NaN
# 1  M. Cvetic, H. Lu, C.N. Pope  Class.Quant.Grav.
# 2     Y.S. Myung, Gungwon Kang                NaN
# 3               Adam D. Helfer          Phys.Rev.
# 4      J. Fuchs, C. Schweigert                NaN
#
#                                             abstract
# 0  these are notes based on lectures given at tas...
# 1  we point out that massive gauged supergravity ...
# 2  recently ivanov and volovich hep-th 9912242 cl...
# 3  quantum fields responding to moving mirrors ha...
# ...

# %%
nodes.describe()
# Out:
#                  id          year
# count  2.777000e+04  27770.000000
# mean   6.096134e+06   1998.009039
# std    4.581677e+06      3.124684
# min    1.001000e+03   1992.000000
# 25%    2.041122e+05   1995.000000
# 50%    9.405182e+06   1998.000000
# 75%    9.705204e+06   2001.000000
# max    9.912293e+06   2003.000000

# %%
nodes_header = ["id", "year", "title", "authors", "journal", "abstract"]
nodes_preprocessed = pd.read_csv(path_to_data+"nodes_preprocessed.csv", names=nodes_header)
nodes_preprocessed.head()
# Out:
#      id  year                                              title  \
# 0    id  year                                              title
# 1  1001  2000               ['compactif', 'geometri', 'dualiti']
# 2  1002  2000  ['domain', 'wall', 'massiv', 'gaug', 'supergra...
# 3  1003  2000  ['comment', 'metric', 'fluctuat', 'brane', 'wo...
# 4  1004  2000       ['move', 'mirror', 'thermodynam', 'paradox']
#
#                                authors                     journal  \
# 0                              authors                     journal
# 1                ['paul s. aspinwall']                         NaN
# 2  ['m. cvetic', 'h. lu', 'c.n. pope']  ['class', 'quant', 'grav']
# 3       ['y.s. myung', 'gungwon kang']                         NaN
# 4                   ['adam d. helfer']             ['phys', 'rev']
#
#                                             abstract
# 0                                           abstract
# 1  ['note', 'base', 'lectur', 'given', 'tasi99', ...
# ...

# %%
nodes_preprocessed.describe()
# Out:
#              id   year                         title  \
# count     27771  27771                         27771
# unique    27771     13                         27496
# top     9702094   2002  ['black', 'hole', 'entropi']
# freq          1   3335                             7
#
#                                            authors           journal  \
# count                                        23738             20299
# unique                                       15834               280
# top     ["shin'ichi nojiri", 'sergei d. odintsov']  ['phys', 'lett']
# freq                                            38              3575
#
#                                                  abstract
# count                                               27771
# unique                                              27765
# top     ['comment', 'start', 'paper', 'hep-th', '01060...
# freq                                                    3
